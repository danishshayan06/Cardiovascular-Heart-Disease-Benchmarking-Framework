# %%
import torch
import rtdl
import sklearn
import imblearn

print("✅ Environment is fully integrated with VS Code!")
print(f"PyTorch version: {torch.__version__}")
print(f"Ready for Phase 2 implementation on heart disease data.")
# Out:
# ✅ Environment is fully integrated with VS Code!
# PyTorch version: 1.13.1+cpu
# Ready for Phase 2 implementation on heart disease data.
